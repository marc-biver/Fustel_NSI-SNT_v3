# %% [markdown]
# <h1 class="alert alert-info"><center>2<sup>nde</sup> 9 &mdash; SNT &mdash; TP Internet</center></h1>

# %% [markdown]
# <p><b>Le but de ce TP est de voir en pratique les notions vues en cours autour du fonctionnement des réseaux et d'internet.</b></p>

# %% [markdown]
# <h3 class="alert alert-warning"><u>ATTENTION: Utilisation de Jupyter Notebook:</u><br><br>
#     Pour saisir des réponses, double cliquer sur les messages "ECRIRE LA REPONSE ICI" et taper votre réponse.<br><br>
#     Terminer en tapant simultanément sur les touches <kbd>Shift<span>&uarr;</span></kbd> et <kbd>Enter<span>&crarr;</span></kbd>.<br><br>
#     <bold>Après chaque saisie de réponse ainsi faite taper sur la touche <kbd> S </kbd> pour sauver votre travail.<br><br><br>
#         <font color="red"><center>Si vous ne sauvez pas votre travail, vous le perdrez - et votre note perdra les points qui vont avec...</center></h3><br />

# %% [markdown]
# <h2 class="alert alert-info">Exercice 1 : vérifier la configuration réseau de votre machine</h2>

# %% [markdown]
# Dans le menu démarrer (dans la zone "Taper ici pour rechercher"), taper `cmd` puis sur la touche <kbd>Enter<span>&crarr;</span></kbd><br>
#
# Vous venez d'ouvrir la ligne de commande Windows - une interface texte qui permet de donner des ordres à l'ordinateur sous forme de commandes.
#
# <i>Conseil: pour que ce soit plus lisible, passez la fenêtre de ligne de commande en plein écran.</i><br><br>
# Taper `ipconfig /all` puis <kbd>Enter<span>&crarr;</span></kbd><br>

# %% [markdown]
# 1. Quelle est l'adresse IP (ipv4) de votre machine?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 2. Quelle est l'adresse MAC (adresse physique) de la carte réseau de votre ordinateur?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 3. Repensez au cours: si vous éteignez votre ordinateur aura-t-il toujours une adresse MAC? Une adresse IP? (expliquez brièvement pourquoi)

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 4. Quelle est l'adresse IP (ipv4) de la machine de votre voisin?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 5. Quelle est la passerelle par défaut à laquelle se connecte votre ordinateur?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 6. Repensez au cours que l'on a fait sur internet et les réseaux: quelle est le rôle de cette passerelle? Vers quoi est-elle une passerelle selon vous?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# <h2 class="alert alert-info">Exercice 2 : allons plus loin - comment est-on vus de l'extérieur?</h2>

# %% [markdown]
# Dans un navigateur internet (celui où cette page est ouverte par exemple), utilisez google pour trouver l'adresse IP de votre machine telle qu'elle est vue de l'extérieur (on appelle ça une "IP publique").

# %% [markdown]
# 1. Quelle est cette adresse? Est-elle la même que celle que nous avons obtenue par ipconfig, plus haut?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 2. Quelle est l'adresse IP publique de la machine de votre voisin? Comment expliquez-vous ça (référez-vous au schéma ci-dessous au besoin)?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# <h4>Une représentation graphique de IP privée // IP publique:</h4><br>
# <img alt="IP privée / publique" style="border-width:0" width="45%" height="45%" src="https://academy.avast.com/hs-fs/hubfs/New_Avast_Academy/Public%20vs.%20local%20IP%20addresses%20(Academy)/Public-vs-Private-IP-Addresses-01-FR.png?width=1328&height=1448&name=Public-vs-Private-IP-Addresses-01-FR.png" /><br />

# %% [markdown]
# 2. En vous aidant du schéma ci-dessus, expliquez brièvement qui utilise votre adresse IP interne et qui utilise votre adresse IP publique.

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# <h2 class="alert alert-info">Exercice 3 : le "ping"</h2>

# %% [markdown]
# Dans l'invite de commande ouverte à l'exercice 1, taper `ping lemonde.fr` puis sur la touche <kbd>Enter<span>&crarr;</span></kbd>. <i>(Note: lemonde.fr est le site web du journal quotidien français Le Monde.)</i><br>
#
# Un `ping` est une commande qui envoie des paquets de test un par un à un destinataire et qui mesure le temps que met le destinataire à répondre - c'est un outil utilisé pour déterminer si une machine est joignable depuis la vôtre et pour mesurer sommairement la qualité de la connexion avec elle.

# %% [markdown]
# 1. Quelle est l'adresse IP du site web du journal Le Monde? Combien de temps en moyenne met le serveur à répondre?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 2. Faites à présent un `ping samoagovt.ws` (c'est le site web du gouvernement des Iles Samoa, situées en Océanie, à plus de 15.000 kilomètres d'ici). Quelle est l'adresse IP trouvée? Combien de temps en moyenne met le serveur à répondre?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 3. Faites à présent un `ping` vers l'adresse IP de l'ordinateur de votre voisin (trouvée lors de la première question) Combien de temps en moyenne met le serveur à répondre?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 4. Classez les trois requêtes ping que vous venez de faire de la plus rapide à la plus lente. Comment expliquez-vous cet ordre?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 5. Faites à présent un ping de l'adresse IP publique de votre ordinateur? Que constatez-vous? Comment l'expliquez-vous?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# <h2 class="alert alert-info">Exercice 4 : le "tracert"</h2>

# %% [markdown]
# On a vu en cours que les paquets qui transitent sur internet sont "routés" par le protocole TCP implémenté dans des routeurs. La commande `tracert` ("trace route") permet de visualiser la route prise par des paquets envoyés à des destinataires.
#
# Dans l'invite de commande ouverte à l'exercice 1, taper successivement:
# - a) `tracert` puis l'adresse IP de votre ordinateur (trouvée à la question 1) puis sur la touche <kbd>Enter<span>&crarr;</span></kbd>.
# - b) `tracert` puis l'adresse IP de l'ordinateur du voisin puis sur la touche <kbd>Enter<span>&crarr;</span></kbd>.
# - c) `tracert lemonde.fr` puis sur la touche <kbd>Enter<span>&crarr;</span></kbd>.
# - d) `tracert samoagovt.ws` puis sur la touche <kbd>Enter<span>&crarr;</span></kbd>.

# %% [markdown]
# 1. Qu'est-ce qu'ont en commun les résultats des commandes c et d ci-dessus? Comment l'expliquez-vous?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 2. Pourquoi le nombre de "sauts" en a et en b est-il le même?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 3. Combien y a-t-il de sauts en c? Et en d?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# <h2 class="alert alert-info">Exercice 5 : les câbles sous-marins</h2>

# %% [markdown]
# Aller sur le site [SubmarineCableMap](https://www.submarinecablemap.com).<br><br>
# Rechercher le câble nommé `SeaMeWe-3`.

# %% [markdown]
# 1. Quelle est sa longueur totale?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 2. Repérez où se trouvent les iles Samoa - pensez-vous qu'il est possible que les paquets de votre "ping" vers le site du gouvernement des Samoa aient emprunté ce câble?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 3. Expliquez pourquoi il y a moins de sauts pour atteindre le serveur du gouvernement des Samoa que celui du journal le Monde mais qu'à l'inverse c'est plus rapide d'atteindre celui du Monde.

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# <h2 class="alert alert-info">Exercice 6 : la qualité de la connexion</h2>

# %% [markdown]
# Aller sur le site [Aménagement Numérique du gouvernement français](https://www.amenagement-numerique.gouv.fr/fr/garantir-du-tres-haut-debit-tous-2022).<br><br>
# Prendre connaissance du premier schéma de la page d'accueil.

# %% [markdown]
# 1. A partir de quel débit est-on en "très haut débit"? Et à partir de combien en "excellent débit"?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# Aller sur le [site d'analyse de sa vitesse de connexion](https://www.echosdunet.net/dossiers/test-ping).<br><br>
# Lancer le test (et le laisser complètement se terminer).

# %% [markdown]
# 2. A priori quelle commande utilise ce test pour mesurer les temps de réponse?

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 3. Quels débits sont mesurés pour l'envoi et pour la réception? Diriez-vous que le réseau ici est haut? Très haut? Excellent? (par rapport aux définitions du gouvernement français précédentes)

# %% [raw]
# ECRIRE LA REPONSE ICI

# %% [markdown]
# 4. Pour quelles opérations est-ce que le débit d'envoi (aussi appelé <i>upload</i>) est important? Et le débit de réception (aussi appelé <i>download</i>)?

# %% [raw]
# ECRIRE LA REPONSE ICI
