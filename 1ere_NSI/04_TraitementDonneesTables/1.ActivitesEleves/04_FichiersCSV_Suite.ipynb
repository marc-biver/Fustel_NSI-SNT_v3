# %% [markdown]
# <h1 class="alert alert-info"><center>Activité : traitement de données en table 2/2</center></h1>

# %% [markdown]
# <p>Le but de cette activité est de mettre en oeuvre sur des exemples pratiques ce que vous avez appris sur la manipulation des fichiers CSV et des données en table.<br><br>
# <strong>Dans tous les fichiers CSV utilisés dans cette activité, les données sont séparées par des virgules <code>,</code><strong></p>

# %% [markdown]
# <h2 class="alert alert-warning"><center>Exercices</center></h2>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 1 : valider les clés d'un dictionnaire</h2>

# %% [markdown]
# 1. La fonction `validation_clés` ci-dessous prend en paramètre un dictionnaire `dico` et une liste `liste_clés` de clés. Elle renvoie `True` si les clés du dictionnaire `dico` sont **exactement** les clés présentes dans la liste `liste_clés`, et `False` sinon.
#
# Compléter cette fonction.

# %%
def validation_clés(dico, liste_clés):
    if len(dico) != len(liste_clés) : # il n'y a pas le même nombre de clés
        return ...
    for clé in dico :
        if clé ... liste_clés : # si une clé de dico n'est pas un élément de liste_clés
            return ...
    return ... # toutes les clés sont les mêmes

# %% [markdown]
# Les quatre cellules suivantes permettent de tester votre fonction. Elles doivent toutes renvoyer `True` lors de leur exécution.

# %%
dico = {'orange':40, 'poire':25, 'fraise':30}
liste_clés = ['orange', 'poire']
validation_clés(dico, liste_clés) == False

# %%
dico = {'orange':40, 'poire':25, 'fraise':30}
liste_clés = ['orange', 'poire','fraise', 'abricot']
validation_clés(dico, liste_clés) == False

# %%
dico = {'orange':40, 'poire':25, 'fraise':30, 'abricot':15}
liste_clés = ['orange', 'poire','fraise', 'abricot']
validation_clés(dico, liste_clés) == True

# %%
dico = {'orange':40, 'poire':25, 'fraise':30, 'abricot':15}
liste_clés = ['abricot', 'orange', 'fraise', 'poire']
validation_clés(dico, liste_clés) == True

# %% [markdown]
# 2. Compléter la fonction ci-dessous qui prend en paramètre deux dictionnaires `dico1` et `dico2` et qui renvoie `True` si les deux dictionnaires ont exactement les mêmes clés et `False` sinon?

# %%
def clés_identiques(dico1, dico2):
    return ... # à compléter en une seule instruction

# %% [markdown]
# Les quatre cellules suivantes permettent de tester votre fonction. Elles doivent toutes renvoyer `True` lors de leur exécution.

# %%
dico1 = {'orange':40, 'poire':25, 'fraise':30}
dico2 = {'orange':50, 'poire':12}
clés_identiques(dico1, dico2) == False

# %%
dico1 = {'orange':40, 'poire':25, 'fraise':30}
dico2 = {'orange':50, 'poire':12, 'fraise': 26, 'abricot':55}
clés_identiques(dico1, dico2) == False

# %%
dico1 = {'orange':40, 'poire':25, 'fraise':30, 'abricot':15}
dico2 = {'orange':50, 'poire':12, 'fraise': 26, 'abricot':55}
clés_identiques(dico1, dico2) == True

# %%
dico1 = {'orange':40, 'poire':25, 'fraise':30, 'abricot':15}
dico2 = {'abricot':55, 'orange':50, 'fraise': 26, 'poire':12}
clés_identiques(dico1, dico2) == True

# %% [markdown]
# <h2 class="alert alert-info">Exercice 2 : structure d'un fichier CSV</h2>

# %% [markdown]
# 1. Compléter la fonction suivante qui prend en paramètre une chaîne de caractères `nom_fichier` correspond au nom d'un fichier CSV et qui renvoie la table des données associée sous la forme d'une liste de dictionnaires dont les clés sont les noms des différents champs du fichier CSV.

# %%
import csv

def importation_données_csv(nom_fichier):
    # test sur l'extension du fichier
    extension = ...
    assert extension == 'csv', 'le fichier doit être un fichier CSV'
    
    # récupération des données
    with ... as fichier:
        table = ...
    return table

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre code. La première renvoie une erreur d'assertion sur l'extension du fichier. Les deux suivantes renvoie la table des données des deux fichiers CSV passés en paramètre.

# %%
importation_données_csv('erreur.pdf')

# %%
importation_données_csv('Inventeurs.csv')

# %%
importation_données_csv('Bibliotheque.csv')

# %% [markdown]
# 2. Compléter la fonction suivante qui prend en paramètre une chaîne de caractères `nom_fichier` correspond au nom d'un fichier CSV et qui renvoie un tuple de deux éléments, le premier élément étant le nombre d'enregistrements du fichier et le second élément étant la liste des champs du fichier.

# %%
def structure_csv(nom_fichier):
    table = ... # récupération de la table des données
    return ..., list(...)

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre code. La première renvoie une erreur d'assertion sur l'extension du fichier. Les deux suivantes renvoie `True`.

# %%
structure_csv('erreur.pdf')

# %%
structure_csv('Inventeurs.csv') == (12, ['Nom', 'Prénom', 'Pays', 'Naissance', 'Mort', 'Invention'])

# %%
structure_csv('Bibliotheque.csv') == (11, ['Titre', 'Auteur', "Nombre d'exemplaires"])

# %% [markdown]
# <h2 class="alert alert-info">Exercice 3 : ajouter des enregistrements</h2>

# %% [markdown]
# On désire à présent enrichir la base de données associée au fichier `Bibliotheque.csv` par des ouvrages situés dans le fichier `Bibliotheque_ajout.txt`.
#
# 1. Compléter les instructions ci-dessous afin de voir l'intégralité du contenu du fichier `Bibliotheque_ajout.txt`, ligne à ligne.

# %%
with open(..., ..., encoding = 'utf-8') as fichier:
    contenu = fichier.....split(...)
contenu

# %% [markdown]
# 2. A quoi correspond la première ligne de ce fichier ? Comment est finalement formaté ce fichier ?

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# 3. Compléter les instructions ci-dessous afin de convertir le contenu du fichier texte en une liste de dictionnaires comme dans le cas d'un fichier CSV.

# %%
liste_champs = contenu[...].split(...) # récupération de la liste de champs
données = [] # liste pour stocker les dictionnaires
for j in range(1,len(contenu)): # parcours des lignes du fichier autre que la ligne d'entête
    donnée_ligne = ... # récupération des données de la ligne numéro j
    données.append({liste_champs[i]:donnée_ligne[i] for i in range(...)})

# %% [markdown]
# Vérifier le résultat en exécutant la cellule suivante :

# %%
données

# %% [markdown]
# 4. Compléter les instructions ci-dessous afin de vérifier que les trois champs du fichier texte sont bien les mêmes champs utilisés par le fichier CSV.

# %%
liste_champs_csv = structure_csv(...)[...]
validation_clés(..., ...)

# %% [markdown]
# A quoi sert cette vérification ?

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# 5. Compléter alors les instructions ci-dessous pour fusionner les deux tables.

# %%
with open('Bibliotheque.csv', 'r', encoding = 'utf-8') as fichier:
        table = ... # récupération de la table associée au fichier Bibliotheque.csv
table_fusion = ... # fusion des tables table et données

# %% [markdown]
# Vérifier le résultat en exécutant la cellule suivante :

# %%
table_fusion

# %% [markdown]
# <h2 class="alert alert-warning"><center>Mini-projet</center></h2>

# %% [markdown]
# <h2 class="alert alert-info">Exercice : gestion d'une bibliothèque</h2>

# %% [markdown]
# On considère dans cet exercice la base de données associée au fichier `Bibliotheque.csv`.
#
# 1. Charger les données dans une liste de dictionnaires que l'on nommera `bib`.<br><br>
# 2. Définir une fonction `auteurs` qui renvoie la liste des auteurs de la bibliothèque `bib`.<br>Par exemple, l'instruction `auteurs(bib)` renvoie la liste `['Victor Hugo', 'J. K. Rowling', 'Laure Dinateur']`.<br><br>
# 3. Définir une fonction `titres_disponibles` renvoyant l'ensemble des livres disponibles à l'emprunt à la bibliothèque `bib`.<br><br>
# 4. Définir une fonction `titres_auteur` renvoyant l'ensemble des livres de l'auteur `nom` disponibles à l'emprunt à la bibliothèque `bib`.<br>Par exemple, l'instruction `titres_auteur(bib, "Victor Hugo")` renvoie la liste `['Les misérables', 'Notre Dame de Paris']`.

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Licence Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />Ce document  est mis à disposition selon les termes de la <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licence Creative Commons Attribution -  Partage dans les Mêmes Conditions 4.0 International</a>.
# Pour toute question : <a href="mailto:charles.poulmaire@ac-versailles.fr">charles.poulmaire@ac-versailles.fr</a> ou <a href="mailto:pascal.remy@ac-versailles.fr">pascal.remy@ac-versailles.fr</a>
